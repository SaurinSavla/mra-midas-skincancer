# %%
import numpy as np
import pandas as pd

# %%
print(np.__version__)
# Out:
# 1.24.2

# %%
print(pd.__version__)
# Out:
# 2.2.0

# %%
df = pd.read_excel('C:/Data/DJ/SkinCancer/release_midas.xlsx')
df
# Out:
#       Unnamed: 0  midas_record_id       midas_file_name midas_iscontrol  \
# 0              0                1   s-prd-398966407.jpg              no
# 1              1                1   s-prd-398966642.jpg              no
# 2              2                1   s-prd-398966845.jpg              no
# 3              3                1   s-prd-398967381.jpg              no
# 4              4                1   s-prd-398967587.jpg              no
# ...          ...              ...                   ...             ...
# 3411        3411              814  s-prd-840869645.jpeg             yes
# 3412        3412              814  s-prd-840869646.jpeg             yes
# 3413        3413              815   s-prd-856668096.jpg              no
# 3414        3414              815   s-prd-856665590.jpg              no
# 3415        3415              815   s-prd-856665592.jpg              no
#
#      midas_distance midas_location                midas_path  \
# 0               1ft          chest          malignant- sccis
# 1               6in          chest          malignant- sccis
# 2            dscope          chest          malignant- sccis
# 3               1ft   l lower back  benign-melanocytic nevus
# 4            dscope   l lower back  benign-melanocytic nevus
# ...             ...            ...                       ...
# 3411  n/a - virtual           back                       NaN
# 3412  n/a - virtual           back                       NaN
# 3413         dscope     lower back  benign-melanocytic nevus
# 3414            6in     lower back  benign-melanocytic nevus
# 3415            1ft     lower back  benign-melanocytic nevus
#
#                                        midas_pathreport midas_gender  \
# 0     focal squamous cell carcinoma, in situ,   aris...       female
# 1     focal squamous cell carcinoma, in situ,   aris...       female
# 2     focal squamous cell carcinoma, in situ,   aris...       female
# 3     intradermal melanocytic nevus, transected at t...       female
# 4     intradermal melanocytic nevus, transected at t...       female
# ...                                                 ...          ...
# 3411                                                  0         male
# 3412                                                  0         male
# 3413  mildly dysplastic compound melanocytic nevus, ...       female
# 3414  mildly dysplastic compound melanocytic nevus, ...       female
# 3415  mildly dysplastic compound melanocytic nevus, ...       female
#
#       midas_age                                  midas_fitzpatrick  \
# 0            80                            ii fair skin, blue eyes
# 1            80                            ii fair skin, blue eyes
# 2            80                            ii fair skin, blue eyes
# 3            80                            ii fair skin, blue eyes
# 4            80                            ii fair skin, blue eyes
# ...         ...                                                ...
# 3411         60                            ii fair skin, blue eyes
# 3412         60                            ii fair skin, blue eyes
# 3413         52  i pale white skin, blue/green eyes, blond/red ...
# 3414         52  i pale white skin, blue/green eyes, blond/red ...
# 3415         52  i pale white skin, blue/green eyes, blond/red ...
#
#      midas_melanoma midas_ethnicity midas_race          clinical_impression_1  \
# 0                no              no      white                7-malignant-bcc
# 1                no              no      white                7-malignant-bcc
# 2                no              no      white                7-malignant-bcc
# 3                no              no      white     1-benign-melanocytic nevus
# 4                no              no      white     1-benign-melanocytic nevus
# ...             ...             ...        ...                            ...
# 3411            yes              no      white  2-benign-seborrheic keratosis
# 3412            yes              no      white  2-benign-seborrheic keratosis
# 3413             no              no      white     1-benign-melanocytic nevus
# 3414             no              no      white     1-benign-melanocytic nevus
# 3415             no              no      white     1-benign-melanocytic nevus
#
#            clinical_impression_2       clinical_impression_3  length_(mm)  \
# 0                 6-benign-other  1-benign-melanocytic nevus          8.0
# 1                 6-benign-other  1-benign-melanocytic nevus          8.0
# 2                 6-benign-other  1-benign-melanocytic nevus          8.0
# 3                 6-benign-other              6-benign-other          6.0
# 4                 6-benign-other              6-benign-other          6.0
# ...                          ...                         ...          ...
# 3411  1-benign-melanocytic nevus                         NaN          6.0
# 3412  1-benign-melanocytic nevus                         NaN          6.0
# 3413       11-malignant-melanoma  1-benign-melanocytic nevus         10.0
# 3414       11-malignant-melanoma  1-benign-melanocytic nevus         10.0
# 3415       11-malignant-melanoma  1-benign-melanocytic nevus         10.0
#
#       width_(mm)
# 0            5.0
# 1            5.0
# 2            5.0
# 3            5.0
# 4            5.0
# ...          ...
# 3411         5.0
# 3412         5.0
# 3413         9.0
# 3414         9.0
# 3415         9.0
#
# [3416 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns_to_plot = ['midas_age', 'length_(mm)', 'width_(mm)']
for col in columns_to_plot:
    plt.figure()
    sns.histplot(df[col])
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\91935\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
#       2 for col in columns_to_plot:
#       3     plt.figure()
# ----> 4     sns.histplot(df[col])
#       5     plt.title(f'Distribution of {col}')
#       6     plt.show()
#
# File c:\Users\91935\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\91935\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'length'
